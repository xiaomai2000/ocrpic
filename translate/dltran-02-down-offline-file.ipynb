# %%
# Dl-translate lab 02:
# Test download model files offline

# %%
# !pip install dl-translate

# %%
import shutil
import huggingface_hub as hub

# %%
dirname = hub.snapshot_download("facebook/m2m100_418M")
# Out:
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# ...

# %%
shutil.copytree(dirname, "cached_model_m2m100")  # Copy to a permanent folder
# Out:
# 'cached_model_m2m100'

# %%
# !ls -l
# Out:
# total 8
# drwxr-xr-x 2 root root 4096 Aug 25 13:45 cached_model_m2m100
# drwxr-xr-x 1 root root 4096 Aug 23 13:35 sample_data

# %%
# !cd cached_model_m2m100 && ls -l
# Out:
# total 3786864
# -rw-r--r-- 1 root root        908 Aug 25 13:44 config.json
# -rw-r--r-- 1 root root        233 Aug 25 13:44 generation_config.json
# -rw-r--r-- 1 root root 1935796948 Aug 25 13:45 pytorch_model.bin
# -rw-r--r-- 1 root root       4603 Aug 25 13:44 README.md
# -rw-r--r-- 1 root root 1935781288 Aug 25 13:45 rust_model.ot
# -rw-r--r-- 1 root root    2423393 Aug 25 13:44 sentencepiece.bpe.model
# -rw-r--r-- 1 root root       1140 Aug 25 13:44 special_tokens_map.json
# -rw-r--r-- 1 root root        272 Aug 25 13:44 tokenizer_config.json
# -rw-r--r-- 1 root root    3708092 Aug 25 13:44 vocab.json

# %%
# !ls -l
# Out:
# total 8
# drwxr-xr-x 2 root root 4096 Aug 25 13:45 cached_model_m2m100
# drwxr-xr-x 1 root root 4096 Aug 23 13:35 sample_data

# %%
dirname2 = hub.snapshot_download("facebook/nllb-200-distilled-600M")  #size is 2.46G
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# ...
