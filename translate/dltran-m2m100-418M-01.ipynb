# %%
import datetime

# %%
# !pip install transformers SentencePiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 40.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.7 MB/s eta 0:00:00
# ...

# %%
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")

# %%
hi_text = "जीवन एक चॉकलेट बॉक्स की तरह है।"
chinese_text = "生活就像一盒巧克力。"

# %%
# translate Hindi to French
tokenizer.src_lang = "hi"
encoded_hi = tokenizer(hi_text, return_tensors="pt")
generated_tokens = model.generate(**encoded_hi, forced_bos_token_id=tokenizer.get_lang_id("fr"))
tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
# => "La vie est comme une boîte de chocolat."
# Out:
# ['La vie est comme une boîte de chocolat.']

# %%
# translate Chinese to English
print(datetime.datetime.now())

tokenizer.src_lang = "zh"
encoded_zh = tokenizer(chinese_text, return_tensors="pt")
generated_tokens = model.generate(**encoded_zh, forced_bos_token_id=tokenizer.get_lang_id("en"))
print(tokenizer.batch_decode(generated_tokens, skip_special_tokens=True))
# => "Life is like a box of chocolate."

print(datetime.datetime.now())
# Out:
# 2023-08-26 16:39:12.211560
# ['Life is like a box of chocolate.']
# 2023-08-26 16:39:18.591082

# %%
###
#    "m2m100": ["af", "am", "ar", "ast", "az", "ba", "be", "bg", "bn", "br", "bs", "ca", "ceb", "cs",
#           "cy", "da", "de", "el", "en", "es", "et", "fa", "ff", "fi", "fr", "fy", "ga", "gd", "gl", "gu",
#           "ha", "he", "hi", "hr", "ht", "hu", "hy", "id", "ig", "ilo", "is", "it", "ja", "jv", "ka", "kk",
#           "km", "kn", "ko", "lb", "lg", "ln", "lo", "lt", "lv", "mg", "mk", "ml", "mn", "mr", "ms", "my",
#           "ne", "nl", "no", "ns", "oc", "or", "pa", "pl", "ps", "pt", "ro", "ru", "sd", "si", "sk", "sl",
#           "so", "sq", "sr", "ss", "su", "sv", "sw", "ta", "th", "tl", "tn", "tr", "uk", "ur", "uz", "vi",
#           "wo", "xh", "yi", "yo", "zh", "zu"],

# %%
"""
==============  THai ==================
面包、冰淇淋、电话卡、  矿泉水、咖啡
ขนมปัง ,  ไอศครีม ,  บัตรโทรศัพท์ ,  น้ำแร่ ,  กาแฟ

酒店，金额， 单位，单价，  数量，公司
होटल,  राशि,  इकाई, इकाई मूल्य,  मात्रा,  कंपनी


==============  Malay ==================

面包、冰淇淋、电话卡、矿泉水、咖啡
Roti, aiskrim, kad telefon, air mineral, kopi

酒店，金额， 单位，单价，  数量，公司
Hotel, jumlah, unit, harga unit, kuantiti, syarikat
"""

# %%
print(datetime.datetime.now())

#thai_text = 'ขนมปัง'

thai_text = 'ขนมปัง , ไอศครีม , บัตรโทรศัพท์ , น้ำแร่ ,กาแฟ, '
#thai_text = 'होटल, राशि, इकाई, इकाई मूल्य, मात्रा, कंपनी'

tokenizer.src_lang = "th"
encoded_zh = tokenizer(thai_text, return_tensors="pt")
generated_tokens = model.generate(**encoded_zh, forced_bos_token_id=tokenizer.get_lang_id("zh"))
print(tokenizer.batch_decode(generated_tokens, skip_special_tokens=True))

print(datetime.datetime.now())
# Out:
# 2023-08-26 17:02:56.897132
# ['面包, 冰淇淋, 电话卡, 水, 咖啡,']
# 2023-08-26 17:03:11.380613

# %%
print(datetime.datetime.now())

malay_text = 'Roti, aiskrim, kad telefon, air mineral, kopi'

tokenizer.src_lang = "ms"
encoded_zh = tokenizer(malay_text, return_tensors="pt")
generated_tokens = model.generate(**encoded_zh, forced_bos_token_id=tokenizer.get_lang_id("zh"))
print(tokenizer.batch_decode(generated_tokens, skip_special_tokens=True))

print(datetime.datetime.now())
# Out:
# 2023-08-26 17:02:34.299006
# ['面包,冰淇淋,电话卡,矿泉水,咖啡']
# 2023-08-26 17:02:39.920968
